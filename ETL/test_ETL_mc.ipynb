# %%
import pandas as pd
from etl_sdt.extract.excel_extractor import *
# from etl_sdt.transform.data_transfomer import *
from etl_sdt.configs.config_mc import  *
from etl_sdt.utils.logging_config import logger
from etl_sdt.transform.data_transfomer import DictionaryTransformer, FeatureExtractor
from pprint import pprint

df = open_excel(file_path='data\\250319_MDS_merged_Timo_LUKS_completed_3.xlsx')

df = df[1:]
chunks = chunking(df, num_chunks= 50, chunking_variable_id= 'Pat ID')



for i, chunk in enumerate(chunks):
    chunk_json = chunk.to_json(orient='records')
    df_chunk = DictionaryTransformer.read_chuck(chunk_json)

    dict_transf = DictionaryTransformer(column_renaming_map)
    df_chunk = dict_transf.aggregate_dataframe(df_chunk)
    df_chunk = dict_transf.renaming(df_chunk)
    df_chunk = dict_transf.transform_dataframe(df_chunk, data_format_dict= data_type_mapping)
    df_chunk = dict_transf.map_columns_with_partial_labels(df_chunk, label_dict)
    print(df_chunk[['patient_id', 'chemo_type']])
    # extract features (single obs extraction)
    fe = FeatureExtractor(df_chunk, feature_mapping, data_type_mapping)
    df_chunk = fe.process_mc()

    df_chunk = fe.post_process_mc()
    
    records = dict_transf.restructure_to_records(df_chunk, feature_mapping, key_column= 'patient_id')
    dict_transf.export_sample(records, 1)
    
    pprint(records[1])
    break
# Out:
# c:\Users\Admin\miniconda3\envs\sarcoma-dt\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:850: UserWarning: Parsing dates in  %d.%m.%Y  format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   return pd.to_datetime(item, errors='coerce')
#     patient_id chemo_type
# 0       154911       None
# 1       154911       None
# 2       156590       None
# 3       156590       None
# 4       156590       None
# 5       156590       None
# 6       156590       None
# 7       156590       None
# 8       156590       None
# 9       156590  cytotoxic
# 10      215635       None
# 11      215635       None
# 12      280194       None
# 13      310522       None
# 14      345717       None
# 15      345717       None
# 16      345717       None
# 17      345717       None
# 18      383929       None
# 19      383929       None
# 20      390651       None
# 21      390651       None
# 22      390651       None
# 23      471533       None
# 24      471533       None
# 25      471533       None
# 26      644919       None
# 27      644919       None
# 28      645743       None
# 29      679704       None
# 30      679704       None
# 31      679704       None
# 32      679704   targeted
# 33      751890       None
# 34      751890       None
# 35      751890       None
# 36      751890       None
# 37      751890       None
# 38      751890       None
# 39      751890       None
# 40      751890       None
# 41      758485       None
# 42      758485       None
# 43      758485       None
# 44      758485       None
# 45      758485       None
# 46      759888       None
# 47      759888       None
# 48      772232       None
# 49      883980       None
# 50      883980       None
# 51      883980       None
# 52      941190       None
# 53      941190       None
# 54      941190       None
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1536: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1536: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1536: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1536: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1536: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1536: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1546: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1546: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1546: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1546: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1546: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1546: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1553: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1553: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1553: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1553: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1553: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# {'_id': 154911, 'general': {'gender': 'male', 'date_of_diagnosis': Timestamp('2021-01-27 00:00:00'), 'birth_date': np.int64(1942), 'date_death': Timestamp('2021-05-24 00:00:00'), 'date_follow_up': Timestamp('2021-06-22 00:00:00'), 'status': '[3] dead of disease (DOD)', 'age': np.int64(83), 'metastasis_after_first_treatment': np.int64(1)}, 'tumor_characteristics': {'histological_diagnosis': '16.3.2. conventional osteosarcoma', 'grading_fnclcc': 'G3', 'lesion_site': 'B9.2. thoracic spine', 'affected_tissue': 'Bone', 'anatomic_side_lesion': 'right'}, 'treatments': {}, 'diagnosis_treatment_sequence': [{'date_field': Timestamp('2021-03-05 00:00:00'), 'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'), 'fields': {'type_surgery': '[3] Pathological fracture', 'margin_status': 'na'}, 'section': 'surgery'}, {'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'), 'fields': {'chemo_reason': '[0] No therapy'}, 'section': 'chemotherapy'}, {'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'), 'fields': {'radiotherapy_indication': '[0] no radiotherapy'}, 'section': 'radiotherapy'}, {'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'), 'fields': {'Date of extrapulmonary metastasis': Timestamp('2020-12-01 00:00:00'), 'presence_metastasis': '0 no', 'follow_up': 1.0}, 'section': 'metastasis'}]}
# {'_id': 156590,
#  'diagnosis_treatment_sequence': [{'fields': {'radiotherapy_total_dose': 50.0},
#                                    'section': 'radiotherapy'},
#                                   {'fields': {'presence_metastasis': '0 no'},
#                                    'section': 'metastasis'},
#                                   {'date_sarcomaboard': datetime.datetime(2019, 2, 19, 0, 0),
#                                    'fields': {'radiotherapy_indication': '1 '
#                                                                          'preoperative',
#                                               'radiotherapy_total_dose': 50.0},
#                                    'section': 'radiotherapy'},
#                                   {'date_sarcomaboard': datetime.datetime(2019, 5, 7, 0, 0),
#                                    'fields': {'radiotherapy_indication': '1 '
#                                                                          'preoperative'},
#                                    'section': 'radiotherapy'},
#                                   {'date_sarcomaboard': datetime.datetime(2020, 3, 10, 0, 0),
#                                    'fields': {'chemo_reason': 'Palliative'},
#                                    'section': 'chemotherapy'},
#                                   {'date_field': Timestamp('2019-06-14 00:00:00'),
#                                    'fields': {'margin_status': 'R1',
#                                               'tumor_max_size': 115.0,
#                                               'type_surgery': '[1] 1st surgery '
#                                                               'for this '
#                                                               'reason'},
#                                    'section': 'surgery'},
#                                   {'fields': {'chemo_discontinuation': 2.0,
#                                               'chemo_indication': 3.0,
#                                               'chemo_reason': '[4] Palliative',
#                                               'chemo_type': 'cytotoxic'},
#                                    'section': 'chemotherapy'},
#                                   {'date_field': Timestamp('2019-03-05 00:00:00'),
#                                    'fields': {'hyperthermia_additional': '-',
#                                               'radiotherapy_indication': '[1] '
#                                                                          'preoperative',
#                                               'radiotherapy_total_dose': 50.0,
#                                               'redonc_fractions': 25,
#                                               'redonc_fractions_gray': 2,
#                                               'redonc_indication': 1,
#                                               'redonc_total_gray': 50,
#                                               'redonc_type': 1,
#                                               'start_radio': Timestamp('2019-03-05 00:00:00')},
#                                    'section': 'radiotherapy'},
#                                   {'fields': {'Date of pulmonary metastasis': Timestamp('2019-12-20 00:00:00'),
#                                               'date_metastasis': Timestamp('2019-12-20 00:00:00'),
#                                               'follow_up': 1.0,
#                                               'presence_metastasis': '0 no',
#                                               'treatment_metastasis': '[1] '
#                                                                       'Chemotherapy'},
#                                    'section': 'metastasis'}],
#  'general': {'age': np.int64(66),
#              'ajcc_uicc': np.float64(8.0),
#              'birth_date': np.int64(1959),
#              'date_death': Timestamp('2020-10-28 00:00:00'),
#              'date_first_patientcontact': Timestamp('2019-02-12 00:00:00'),
#              'date_follow_up': Timestamp('2020-10-28 00:00:00'),
#              'date_of_diagnosis': Timestamp('2019-02-18 00:00:00'),
#              'gender': 'female',
#              'metastasis_after_first_treatment': np.int64(1),
#              'mitotic_count': 0.0,
#              'sarculator_five': 0.61,
#              'sarculator_ten': 0.61,
#              'status': '3 dead of disease (DOD)'},
#  'treatments': {'Date of 1st local recurrence': Timestamp('2020-05-12 00:00:00'),
#                 'chemo_first_indication': np.float64(3.0),
#                 'complexity_first_planned_surger': np.float64(3.0),
#                 'number_surgeries': np.float64(2.0),
#                 'redonc_first_indication': np.float64(1.0),
#                 'whoops_surgeon': '-'},
#  'tumor_characteristics': {'affected_tissue': 'Deep',
#                            'anatomic_side_lesion': 'right',
#                            'anatomicregion': np.float64(5.0),
#                            'grading_fnclcc': 'G3',
#                            'histological_diagnosis': '2.3.1. dedifferentiated '
#                                                      'liposarcoma',
#                            'initial_metastasis': np.float64(0.0),
#                            'initial_size_a': np.float64(100.0),
#                            'initial_size_b': np.float64(80.0),
#                            'initial_size_c': np.float64(77.0),
#                            'lesion_site': 'D18.4. retro- / extraperitoneal',
#                            'number_metastasis': np.float64(1.0),
#                            'whoops': 'no'}}
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1553: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)

# %%
print(df)
# Out:
#      Institution                                             Pat ID  \
# 1              4                                             154911
# 2              4                                             154911
# 3              4                                             156590
# 4              4                                             156590
# 5              4                                             156590
# ...          ...                                                ...
# 2116           4                                            8476111
# 2117         NaN                                                NaN
# 2118         NaN  dunkelblau markierte Spalten gehören zum MDS u...
# 2119         NaN  hellblau markierte Spalten sind als Info aus d...
# 2120  Metastasen                                  No or Yes angeben
#
#      Alt PID_Timo  Gender Date of birth General Consent agreed  \
# 1             NaN    male          1942                     no
# 2             NaN    male          1942                    NaN
# 3             NaN  female          1959                    NaN
# 4             NaN  female          1959                    NaN
# 5             NaN  female          1959                    NaN
# ...           ...     ...           ...                    ...
# 2116          NaN  female          1988                    yes
# 2117          NaN     NaN           NaN                    NaN
# 2118          NaN     NaN           NaN                    NaN
# 2119          NaN     NaN           NaN                    NaN
# 2120          NaN     NaN           NaN                    NaN
#
#      Date of histological diagnosis type_biopsy_Timo biopsy_neoadjuvant_Timo  \
# 1               2021-01-27 00:00:00              NaN                     NaN
# 2                        27.01.2021              NaN                     NaN
# 3                        18.02.2019              NaN                     NaN
# 4                        18.02.2019              NaN                     NaN
# 5                        18.02.2019              NaN                     NaN
# ...                             ...              ...                     ...
# 2116            2023-11-14 00:00:00              NaN                     NaN
# 2117                            NaN              NaN                     NaN
# 2118                            NaN              NaN                     NaN
# 2119                            NaN              NaN                     NaN
# 2120                            NaN              NaN                     NaN
#
#      Grading (FNCLCC)  ...  \
# 1                  G3  ...
# 2                      ...
# 3                  G3  ...
# 4                      ...
# 5                      ...
# ...               ...  ...
# 2116           [3] G3  ...
# 2117              NaN  ...
# 2118              NaN  ...
# 2119              NaN  ...
# 2120              NaN  ...
#
#      Follow up SB presentation (Reason for SB presentation)  \
# 1                                                   NaN
# 2                     3 in context of primary treatment
# 3
# 4                     3 in context of primary treatment
# 5                     3 in context of primary treatment
# ...                                                 ...
# 2116                                                NaN
# 2117                                                NaN
# 2118                                                NaN
# 2119                                                NaN
# 2120                                                NaN
#
#      (0) OP_619 - Reason for SB presentation_Timo  \
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# ...                                           ...
# 2116                                          NaN
# 2117                                          NaN
# 2118                                          NaN
# 2119                                          NaN
# 2120                                          NaN
#
#      (0) OP_1113 - Specify treatment outside SwissSarcomaNetwork_Timo  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 2116                                                NaN
# 2117                                                NaN
# 2118                                                NaN
# 2119                                                NaN
# 2120                                                NaN
#
#      (0) OP_1115 - Specify current status_Timo  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# ...                                        ...
# 2116                    4 no evidence of tumor
# 2117                                       NaN
# 2118                                       NaN
# 2119                                       NaN
# 2120                                       NaN
#
#      (0) OP_1112 - Follow up SB presentation_Timo (W) Other diagnoses?_Timo  \
# 1                                             NaN                       NaN
# 2                                             NaN                       NaN
# 3                                             NaN                       NaN
# 4                                             NaN                       NaN
# 5                                             NaN                       NaN
# ...                                           ...                       ...
# 2116                                          NaN                       NaN
# 2117                                          NaN                       NaN
# 2118                                          NaN                       NaN
# 2119                                          NaN                       NaN
# 2120                                          NaN                       NaN
#
#      (newest) Patient history (clinics, therapy) - latest to newest_Timo  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 2116                                                NaN
# 2117                                                NaN
# 2118                                                NaN
# 2119                                                NaN
# 2120                                                NaN
#
#       Date of last follow-up                            Status  \
# 1        2021-06-22 00:00:00         [3] dead of disease (DOD)
# 2                        NaN                               NaN
# 3        2020-10-28 00:00:00           3 dead of disease (DOD)
# 4        2020-10-28 00:00:00           3 dead of disease (DOD)
# 5        2020-10-28 00:00:00           3 dead of disease (DOD)
# ...                      ...                               ...
# 2116     2025-01-31 00:00:00  [1] no evidence of disease (NED)
# 2117                     NaN                               NaN
# 2118                     NaN                               NaN
# 2119                     NaN                               NaN
# 2120                     NaN                               NaN
#
#                                             Bemerkungen
# 1     no falsch hinterlegt m.E. -> yes (Erstdiagnose...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 2116                                                NaN
# 2117                                                NaN
# 2118                                                NaN
# 2119                                                NaN
# 2120                                                NaN
#
# [2120 rows x 118 columns]

# %%
from pprint import pprint

for i, chunk in enumerate(chunks):
    chunk_json = chunk.to_json(orient='records')
    df_chunk = DictionaryTransformer.read_chuck(chunk_json)

    dict_transf = DictionaryTransformer(column_renaming_map)
    df_chunk = dict_transf.aggregate_dataframe(df_chunk)
    df_chunk = dict_transf.renaming(df_chunk)
    df_chunk = dict_transf.transform_dataframe(df_chunk, data_format_dict= data_type_mapping)
    
    # extract features (single obs extraction)
    fe = FeatureExtractor(df_chunk, feature_mapping, data_type_mapping)
    df_chunk = fe.process_mc()

    df_chunk = fe.mock_post_process()

    records = dict_transf.restructure_to_records(df_chunk, feature_mapping, key_column= 'patient_id')

    pprint(records[0])
    # break
    # TODO: build the new dictionary for the records 


    # extract at EHR level (multiple obs extraction)

    # add arecoird to  the mongodb
# Out:
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:827: UserWarning: Parsing dates in  %d.%m.%Y  format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   return pd.to_datetime(item, errors='coerce')
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# {'_id': 154911,
#  'diagnosis_treatment_sequence': [{'date_field': Timestamp('2021-03-05 00:00:00'),
#                                    'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'),
#                                    'fields': {'margin_status': 'na',
#                                               'type_surgery': '[3] '
#                                                               'Pathological '
#                                                               'fracture'},
#                                    'section': 'surgery'},
#                                   {'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'),
#                                    'fields': {'chemo_reason': '[0] No therapy'},
#                                    'section': 'chemotherapy'},
#                                   {'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'),
#                                    'fields': {'radiotherapy_indication': '[0] '
#                                                                          'no '
#                                                                          'radiotherapy'},
#                                    'section': 'radiotherapy'},
#                                   {'date_sarcomaboard': Timestamp('2021-02-23 00:00:00'),
#                                    'fields': {'Date of extrapulmonary metastasis': Timestamp('2020-12-01 00:00:00'),
#                                               'follow_up': 1.0},
#                                    'section': 'metastasis'}],
#  'general': {'age': np.int64(83),
#              'birth_date': np.int64(1942),
#              'date_death': Timestamp('2021-05-24 00:00:00'),
#              'date_follow_up': Timestamp('2021-06-22 00:00:00'),
#              'date_of_diagnosis': Timestamp('2021-01-27 00:00:00'),
#              'gender': 'male',
#              'status': '[3] dead of disease (DOD)'},
#  'treatments': {},
#  'tumor_characteristics': {'affected_tissue': 'Bone',
#                            'anatomic_side_lesion': 'right',
#                            'grading_fnclcc': 'G3',
#                            'histological_diagnosis': '16.3.2. conventional '
#                                                      'osteosarcoma',
#                            'lesion_site': 'B9.2. thoracic spine'}}
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# {'_id': 974226,
#  'diagnosis_treatment_sequence': [{'date_field': Timestamp('2021-10-13 00:00:00'),
#                                    'date_sarcomaboard': Timestamp('2021-10-26 00:00:00'),
#                                    'fields': {'margin_status': '[3] unknown',
#                                               'type_surgery': '[1] 1st surgery '
#                                                               'for this '
#                                                               'reason'},
#                                    'section': 'surgery'},
#                                   {'date_sarcomaboard': Timestamp('2021-10-26 00:00:00'),
#                                    'fields': {'chemo_reason': '[0] No therapy'},
#                                    'section': 'chemotherapy'},
#                                   {'date_sarcomaboard': Timestamp('2021-10-26 00:00:00'),
#                                    'fields': {'radiotherapy_indication': '[0] '
#                                                                          'no '
#                                                                          'radiotherapy'},
#                                    'section': 'radiotherapy'},
#                                   {'date_sarcomaboard': Timestamp('2021-10-26 00:00:00'),
#                                    'fields': {'Date of extrapulmonary metastasis': Timestamp('2021-09-08 00:00:00'),
#                                               'Date of pulmonary metastasis': Timestamp('2021-09-08 00:00:00')},
#                                    'section': 'metastasis'}],
#  'general': {'age': np.int64(64),
#              'birth_date': np.int64(1961),
#              'date_death': Timestamp('2021-11-04 00:00:00'),
#              'date_follow_up': Timestamp('2021-11-04 00:00:00'),
#              'date_of_diagnosis': Timestamp('2021-10-08 00:00:00'),
#              'gender': 'male',
#              'status': '[3] dead of disease (DOD)'},
#  'treatments': {},
#  'tumor_characteristics': {'affected_tissue': 'Deep',
#                            'anatomic_side_lesion': 'midline',
#                            'grading_fnclcc': 'G3',
#                            'histological_diagnosis': '23.3.2. angiosarcoma',
#                            'lesion_site': 'D19.4.1. lung',
#                            'whoops': 'no'}}
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# {'_id': 1038772,
#  'diagnosis_treatment_sequence': [],
#  'general': {'age': np.int64(56),
#              'birth_date': np.int64(1969),
#              'gender': 'male'},
#  'treatments': {},
#  'tumor_characteristics': {'affected_tissue': 'Superficial',
#                            'grading_fnclcc': '[0] Not a sarcoma',
#                            'histological_diagnosis': '0 non-neoplastic / tumor '
#                                                      'simulator',
#                            'lesion_site': 'S12.1. regio femoris anterior '
#                                           'proximal'}}
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# {'_id': 1058365,
#  'diagnosis_treatment_sequence': [{'date_field': Timestamp('2016-01-01 00:00:00'),
#                                    'fields': {'margin_status': 'R1',
#                                               'tumor_max_size': 60.0,
#                                               'type_surgery': '[1] 1st surgery '
#                                                               'for this '
#                                                               'reason'},
#                                    'section': 'surgery'},
#                                   {'fields': {'chemo_reason': '[0] No therapy'},
#                                    'section': 'chemotherapy'},
#                                   {'fields': {'hyperthermia_additional': '-',
#                                               'radiotherapy_indication': '[0] '
#                                                                          'no '
#                                                                          'radiotherapy'},
#                                    'section': 'radiotherapy'}],
#  'general': {'age': np.int64(71),
#              'ajcc_uicc': np.float64(2.0),
#              'birth_date': np.int64(1954),
#              'date_first_patientcontact': '17.01.2017',
#              'date_follow_up': Timestamp('2023-12-28 00:00:00'),
#              'date_of_diagnosis': Timestamp('2017-01-17 00:00:00'),
#              'gender': 'female',
#              'mitotic_count': 1.0,
#              'prom_score': np.float64(0.7000000000000001),
#              'prom_score_date': Timestamp('2023-06-13 00:00:00'),
#              'sarculator_five': 0.9400000000000001,
#              'sarculator_ten': 0.9400000000000001,
#              'status': '1 no evidence of disease (NED)'},
#  'treatments': {'Date of 1st local recurrence': Timestamp('2017-01-01 00:00:00'),
#                 'complexity_first_planned_surger': np.float64(1.0),
#                 'disciplines_first_surgery': 6,
#                 'number_surgeries': np.float64(4.0),
#                 'whoops_surgeon': 6},
#  'tumor_characteristics': {'affected_tissue': 'Deep',
#                            'anatomic_side_lesion': 'Left',
#                            'anatomicregion': np.float64(3.0),
#                            'grading_fnclcc': '[1] G1',
#                            'histological_diagnosis': '3.2.10. inflammatory '
#                                                      'myofibroblastic tumor',
#                            'initial_metastasis': np.float64(0.0),
#                            'initial_size_a': np.float64(60.0),
#                            'lesion_site': 'D16.1. dorsum pedis',
#                            'whoops': 'yes'}}
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# ...
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# {'_id': '1066129ksw',
#  'diagnosis_treatment_sequence': [{'date_field': Timestamp('2019-02-19 00:00:00'),
#                                    'date_sarcomaboard': datetime.datetime(2019, 3, 5, 0, 0),
#                                    'fields': {'margin_status': '[1] R1 '
#                                                                'marginal '
#                                                                'margin / R1',
#                                               'tumor_max_size': 200.0,
#                                               'type_surgery': '[1] 1st surgery '
#                                                               'for this '
#                                                               'reason'},
#                                    'section': 'surgery'},
#                                   {'date_sarcomaboard': datetime.datetime(2019, 3, 5, 0, 0),
#                                    'fields': {'chemo_reason': 'no'},
#                                    'section': 'chemotherapy'},
#                                   {'date_sarcomaboard': datetime.datetime(2019, 3, 5, 0, 0),
#                                    'fields': {'radiotherapy_indication': '[0] '
#                                                                          'no '
#                                                                          'radiotherapy'},
#                                    'section': 'radiotherapy'}],
#  'general': {'age': np.int64(91),
#              'birth_date': np.int64(1934),
#              'date_follow_up': Timestamp('2025-03-05 00:00:00'),
#              'date_of_diagnosis': Timestamp('2018-12-24 00:00:00'),
#              'gender': 'male',
#              'status': '[1] no evidence of disease (NED)'},
#  'treatments': {},
#  'tumor_characteristics': {'affected_tissue': 'Deep',
#                            'grading_fnclcc': 'G1',
#                            'histological_diagnosis': '2.2.1. atypical '
#                                                      'lipomatous tumor / well '
#                                                      'differentiated '
#                                                      'liposarcoma',
#                            'lesion_site': 'D18.4. retro- / extraperitoneal',
#                            'whoops': 'no'}}
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1504: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)
# {'_id': '1101660ksw',
#  'diagnosis_treatment_sequence': [{'date_field': Timestamp('2020-03-13 00:00:00'),
#                                    'date_sarcomaboard': Timestamp('2020-05-26 00:00:00'),
#                                    'fields': {'margin_status': 'R0 wide margin '
#                                                                '/ R0',
#                                               'type_surgery': '1 1st surgery '
#                                                               'for this '
#                                                               'reason'},
#                                    'section': 'surgery'},
#                                   {'date_field': Timestamp('2020-03-13 00:00:00'),
#                                    'fields': {'margin_status': 'R0',
#                                               'tumor_max_size': 30.0,
#                                               'type_surgery': '[1] 1st surgery '
#                                                               'for this '
#                                                               'reason'},
#                                    'section': 'surgery'},
#                                   {'fields': {'chemo_reason': 'no'},
#                                    'section': 'chemotherapy'},
#                                   {'fields': {'hyperthermia_additional': '-',
#                                               'radiotherapy_indication': '[0] '
#                                                                          'no '
#                                                                          'radiotherapy'},
#                                    'section': 'radiotherapy'},
#                                   {'fields': {'Date of pulmonary metastasis': Timestamp('2018-09-01 00:00:00')},
#                                    'section': 'metastasis'}],
#  'general': {'age': np.float64(81.0),
#              'ajcc_uicc': np.float64(2.0),
#              'birth_date': np.float64(1944.0),
#              'date_first_patientcontact': '10.02.2020',
#              'date_follow_up': Timestamp('2021-10-21 00:00:00'),
#              'date_of_diagnosis': Timestamp('2020-02-21 00:00:00'),
#              'gender': 'female',
#              'sarculator_five': 0.78,
#              'sarculator_ten': 0.78,
#              'status': '1 no evidence of disease (NED) or AWD'},
#  'treatments': {'complexity_first_planned_surger': np.float64(2.0),
#                 'number_surgeries': np.float64(1.0),
#                 'whoops_surgeon': '-'},
#  'tumor_characteristics': {'affected_tissue': 'Deep',
#                            'anatomic_side_lesion': 'right',
#                            'anatomicregion': np.float64(6.0),
#                            'grading_fnclcc': 'G2-3',
#                            'histological_diagnosis': '5.3.1. leiomyosarcoma '
#                                                      '(excluding skin)',
#                            'initial_metastasis': np.float64(0.0),
#                            'initial_size_a': np.float64(21.0),
#                            'initial_size_b': np.float64(14.0),
#                            'initial_size_c': np.float64(12.0),
#                            'lesion_site': 'D11.1. inguina soft tissues (incl. '
#                                           'funiculus spermaticus & scrotum)',
#                            'whoops': 'no'}}
# c:\Users\Admin\OneDrive - Hochschule Luzern\Desktop\Sarcoma-DT\ETL\etl_sdt\transform\data_transfomer.py:1521: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = self.df.groupby('patient_id').apply(lambda group: self.fill_most_frequent(group, column)).reset_index(drop=True)

# %%
records[0].keys()
# Out:
# dict_keys(['_id', 'general', 'tumor_characteristics', 'treatments', 'diagnosis_treatment_sequence'])

# %%
# Load the Excel file
file_path = '/home/andrea/Desktop/Sarcoma-DT/ETL/data/adjumed_export_20241027-120926.xlsx'
excel_data = pd.ExcelFile(file_path)

# Load each sheet
cases_df = excel_data.parse('Cases')
interventions_df = excel_data.parse('interventions')

# Ensure "Patient ID (PID)" is in each dataset; replace 'Patient ID (PID)' with the actual column name if different
pid_column = 'Patient ID (PID)'

# Sample 200 unique patients by Patient ID from each dataset
cases_sample = cases_df.drop_duplicates(subset=pid_column).sample(n=200, random_state=42)
interventions_sample = interventions_df.drop_duplicates(subset=pid_column).sample(n=200, random_state=42)

# Save the samples to a new Excel file for the test database
with pd.ExcelWriter('ETL/data/adjumed_export_20241027-120926_test.xlsx') as writer:
    cases_sample.to_excel(writer, sheet_name='Cases_Sample', index=False)
    interventions_sample.to_excel(writer, sheet_name='Interventions_Sample', index=False)

print("Sampled data saved to 'test_db_sample.xlsx'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Load the Excel file
#       2 file_path = '/home/andrea/Desktop/Sarcoma-DT/ETL/data/adjumed_export_20241027-120926.xlsx'
# ----> 3 excel_data = pd.ExcelFile(file_path)
#       5 # Load each sheet
#       6 cases_df = excel_data.parse('Cases')
#
# File c:\Users\Admin\miniconda3\envs\sarcoma-dt\lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\Users\Admin\miniconda3\envs\sarcoma-dt\lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\Users\Admin\miniconda3\envs\sarcoma-dt\lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/andrea/Desktop/Sarcoma-DT/ETL/data/adjumed_export_20241027-120926.xlsx'

# %%
from langdetect import detect
from etl_sdt.transform.data_transfomer import DictionaryTransformer
from etl_sdt.transform.nlp_processor import PathologyNERExtractor
from etl_sdt.config import relevant_features
import time

text = ''
ner_genetic = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 

ner_medical = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER")

# %%
start = time.time()

for i in range(1):
    try:

        language = detect(text)


        DT = DictionaryTransformer(renaming_dict)
        translation = DT.detect_and_translate(text, 't5-small')


        ner_genetic.extract_entities(text)
        ner_medical.extract_entities(text) 
    except Exception as e:
        print(e)
stop = time.time()

print(f'Time elapsed: {stop - start}')

# %%
df.to_excel('C:\\Users\\Admin\\OneDrive - Hochschule Luzern\\Desktop\\Sarcoma-DT\\ETL\\data\\adjumed_export_test.xlsx', index=False)

# %%
from etl_sdt.extract.excel_extractor import *
from etl_sdt.transform.data_transfomer import *
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *
from etl_sdt.config import *
from transformers import pipeline

df = pd.read_excel('data/adjumed_export_test.xlsx')

trs = DictionaryTransformer(renaming_dict)
df = trs.aggregate_dataframe(df)
df = trs.renaming(df)
df = trs.transform_dataframe(df, data_format_dict)

ner = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 
df = trs.report_info_extractor(df, ner)

ner_genetic = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 

ner_medical = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER") 

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-de-en")


free_text_columns = ['main_referral_diagnosis']

df = trs.free_text_info_extractor(df, free_text_columns, translator,  ner_genetic,  ner_medical)

records = trs.restructure_data(df, relevant_features, key_column= 'patient_id')

# %%
records

# %%
trs = DictionaryTransformer(renaming_dict)
df = trs.aggregate_dataframe(df)

# %%
df

# %%
df = trs.renaming(df)

# %%
df

# %%
df = trs.transform_dataframe(df, data_format_dict)

# %%
df['report_radiation_oncology_upload']

# %%
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *

ner = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 



df = trs.report_info_extractor(df, ner)

# %%
ner_genetic = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 

ner_medical = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER") 
free_text_columns = ['main_referral_diagnosis']
df = trs.free_text_info_extractor(df, free_text_columns, ner_genetic,  ner_medical)

# %%
records = trs.restructure_data(df, relevant_features, key_column= 'patient_id')

# %%
records

# %%
records[0]['doc_1']['operations']

# %%
from pymongo import MongoClient
from datetime import datetime

# Establish a connection to MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Select the database
db = client['SarcomaDB']
# Select the collection
collection = db['Patients']


def upsert_record(record):
    """
    Update the record if it exists, or insert it if it doesn't.
    
    Args:
    record (dict): The record to be inserted or updated.
    """
    try:
        # Define the query to find the document
        query = {"_id": record["_id"]}
        
        # Define the update operation
        update = {"$set": record}
        
        # Update the document if it exists, insert if it doesn't
        result = collection.update_one(query, update, upsert=True)
        
        if result.upserted_id:
            print(f"Inserted new document with _id: {result.upserted_id}")
        else:
            print(f"Updated existing document with _id: {record['_id']}")
    except Exception as e:
        print(f"Failed to upsert record with _id: {record['_id']}. Error: {e}")




for record in records: 
    upsert_record(record)

# %%
from etl_sdt.extract.excel_extractor import *
from etl_sdt.transform.data_transfomer import *
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *
from etl_sdt.config import *
from transformers import pipeline

df = pd.read_excel('data/adjumed_export_test.xlsx')


trs = DictionaryTransformer(renaming_dict)
df = trs.aggregate_dataframe(df)
df = trs.renaming(df)
df = trs.transform_dataframe(df, data_format_dict)

ner = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 
df = trs.report_info_extractor(df, ner)

ner_genetic = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 

ner_medical = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER") 

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-de-en")


free_text_columns = ['summary_decision_further_strategy']

df = trs.free_text_info_extractor(df, free_text_columns, translator,  ner_genetic,  ner_medical)

# %%
df['summary_decision_further_strategy_pdf']

# %%
import pandas as pd
from openpyxl import load_workbook

def append_to_excel(file_path, data):
    # Load existing workbook
    try:
        book = load_workbook(file_path)
        writer = pd.ExcelWriter(file_path, engine='openpyxl')
        writer.book = book
        
        # Read the existing data
        existing_df = pd.read_excel(file_path)
        
        # Create new data DataFrame
        new_data_df = pd.DataFrame(data)
        
        # Append new data to existing data
        updated_df = pd.concat([existing_df, new_data_df], ignore_index=True)
        
        # Write updated data back to Excel file
        updated_df.to_excel(writer, index=False)
        
        writer.save()
        writer.close()
        
        print(f"Data appended successfully to {file_path}")
    except FileNotFoundError:
        # If file doesn't exist, create it with new data
        new_data_df = pd.DataFrame(data)
        new_data_df.to_excel(file_path, index=False)
        print(f"Excel file created at {file_path} with new data")

# %%
excel_path = "text_annotation_feedback.xlsx"
df_new = df[['summary_decision_further_strategy', 'summary_decision_further_strategy_pdf']]
column_mapping = {
    'main_referral_diagnosis': "Text Segment",
    'main_referral_diagnosis_pdf': "Annotations",
    'summary_files_upload': "Text Segment",
    'summary_files_upload_pdf': "Annotations",
    'summary_decision_further_strategy': "Text Segment",
    'summary_decision_further_strategy_pdf': "Annotations",
}
df_new.rename(columns=column_mapping, inplace=True)

df_new['Type'] = 'Main Referral Diagnosis'
df_new['Annotation'] = None
df_new['Feedback Comment'] = None

append_to_excel(excel_path, df)

# %%
result = collection.insert_one(records[11])

# %%
records[11]['doc_1']['diagnosis']

# %%
# Define the query to find the document
query = {"_id": records[0]["_id"]}

# Define the update operation
update = {"$set": records[0]}
collection.update_one(query, update, upsert=True)

# %%
def get_record_by_id(records, _id):
    for record in records:
        if record['_id'] == _id:
            return record
    return None

get_record_by_id(records, '9341344')

# %%
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *


ner = PathologyNERExtractor(model_name="jnferfer/treatment-disease-NER") 

trs.ner_extract_treatment(df, ner)

# %%
df

# %%
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *

ner_genetic = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 

ner_medical = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER") 

df = trs.report_info_extractor(df, ner_genetic, ner_medical)

# %%
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *

ner_genetic = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 

ner_medical = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER") 
free_text_columns = ['main_referral_diagnosis']
df = trs.free_text_info_extractor(df, free_text_columns, ner_genetic,  ner_medical)

# %%
records[0]['doc_1'].keys()

# %%
def check_duplicates_in_dict(dictionary):
    # Extract values from the dictionary
    values = list(dictionary.values())
    
    # Using a set to track unique values and a list to track duplicates
    seen = set()
    duplicates = set(value for value in values if value in seen or seen.add(value))
    
    # Check if duplicates list is not empty
    has_duplicates = len(duplicates) > 0
    
    # Return a boolean indicating if duplicates exist and the list of duplicates
    return has_duplicates, list(duplicates)
has_duplicates, duplicate_values = check_duplicates_in_dict(renaming_dict)
print("Duplicates exist:", has_duplicates)
print("Duplicate values:", duplicate_values)

# %%
def restructure_data(df, relevant_features, key_column):

        records = []
        key_column = 'patient_id'
        for group_idx, (patient_id, group_df) in enumerate(df.groupby(key_column), start=1):
            
            patient_record = {"_id": patient_id}
            index_l=0
            for idx, (index, row) in enumerate(group_df.iterrows(), start=1):
                index_l+=1
                group_name=f'doc_{index_l}'
                patient_record[group_name] ={}
                
                for group, features in relevant_features.items():
                
                    group_data = []
                
                    
                    row_data = {}
                    for feature in features:
                        renamed_feature = trs.rename_dict.get(feature, feature)
                        try:
                            if row[renamed_feature] !=[] and row[renamed_feature] !=None :
                                if isinstance(row[renamed_feature], list):
                                    for item in row[renamed_feature]:
                                        if not pd.isna(item):
                                            row_data[renamed_feature] = row[renamed_feature]
                                else:
                                    if not pd.isna(row[renamed_feature]):
                                        row_data[renamed_feature] = row[renamed_feature]
                        except KeyError:
                            warnings.warn(f"Failed to allocate key: {renamed_feature}")
                    
                    
                    group_data.append(row_data)
                    
                    if '_n' in group:
                        group=group[:-2]
                        patient_record[group_name][group] = group_data
                    
                    else:
                        patient_record[group] = group_data
            records.append(patient_record)
        
        return records
trs.restructure_data(df_sample, relevant_features, key_column= 'patient_id')

# %%
from etl_sdt.transform.nlp_processor import *
ner = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER") 

value = 'Comparatively to the investigation of 14.12. 2023, there is documented increase in size and metabolic stability of the subcutaneous nodular lesion at the level of the anterior right thigh showing central hypometabolic area secondary to involutional phenomena (current SUVmax 7). Stability of tumor disease interesting the quadriceps femoris muscle and proximal portions of the tibialis anterior muscle of the same limb.'

entities= ner.extract_entities(value)
# column_name = 'summary_decision_further_strategy'
# df, new_column_name = ner._rename_column_ner(df, column_name)
        

def extract_entities_dynamic(entities):
    pathology_info = {}
    
    current_entity = None
    current_text = []

    for entity in entities:
        entity_type = entity['entity']
        entity_text = entity['word'].replace('▁', ' ').strip()
        
        if entity_type.startswith('B-'):
            if current_entity is not None and current_text:
                category = current_entity.split('-')[-1].lower()
                if category not in pathology_info:
                    pathology_info[category] = []
                pathology_info[category].append("".join(current_text).replace('##', ''))

            current_entity = entity_type
            current_text = [entity_text]
        elif entity_type.startswith('I-') and current_entity is not None:
            current_text.append(entity_text)

    if current_entity is not None and current_text:
        category = current_entity.split('-')[-1].lower()
        if category not in pathology_info:
            pathology_info[category] = []
        pathology_info[category].append("".join(current_text).replace('##', ''))

    return pathology_info

annotations = extract_entities_dynamic(entities)
print(annotations)

# %%
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *

pdf_path ='C:/Users/Admin/OneDrive - Hochschule Luzern/Desktop/Sarcoma-DT/ETL/data/pdfs/Histo definitiv.pdf'
value = extract_text_from_pdf(pdf_path, detect_vertical_text=False, word_margin=0.1)
ner = PathologyNERExtractor(model_name="Clinical-AI-Apollo/Medical-NER") 
entities= ner.extract_entities(value)
# column_name = 'summary_decision_further_strategy'
# df, new_column_name = ner._rename_column_ner(df, column_name)
        

def extract_entities_dynamic(entities):
    pathology_info = {}
    
    current_entity = None
    current_text = []

    for entity in entities:
        entity_type = entity['entity']
        entity_text = entity['word'].replace('▁', ' ').strip()
        
        if entity_type.startswith('B-'):
            if current_entity is not None and current_text:
                category = current_entity.split('-')[-1].lower()
                if category not in pathology_info:
                    pathology_info[category] = []
                pathology_info[category].append("".join(current_text).replace('##', ''))

            current_entity = entity_type
            current_text = [entity_text]
        elif entity_type.startswith('I-') and current_entity is not None:
            current_text.append(entity_text)

    if current_entity is not None and current_text:
        category = current_entity.split('-')[-1].lower()
        if category not in pathology_info:
            pathology_info[category] = []
        pathology_info[category].append("".join(current_text).replace('##', ''))

    return pathology_info

annotations = extract_entities_dynamic(entities)
print(annotations)

# %%
annotations = extract_entities_dynamic(entities)
print(annotations)

# %%
records = []
key_column = 'patient_id'
for group_idx, (patient_id, group_df) in enumerate(df.groupby(key_column), start=1):
    
    patient_record = {"_id": patient_id}
    index_l=0
    for idx, (index, row) in enumerate(group_df.iterrows(), start=1):
        index_l+=1
        group_name=f'doc_{index_l}'
        patient_record[group_name] ={}
        
        for group, features in relevant_features.items():
        
            group_data = []
        
            
            row_data = {}
            for feature in features:
                renamed_feature = trs.rename_dict.get(feature, feature)
                try:
                    if row[renamed_feature] !=[] and row[renamed_feature] !=None: row_data[renamed_feature] = row[renamed_feature]
                except KeyError:
                    warnings.warn(f"Failed to allocate key: {renamed_feature}")
            
            
            group_data.append(row_data)
            
            if '_n' in group:
                group=group[:-2]
                patient_record[group_name][group] = group_data
            
            else:
                patient_record[group] = group_data
    records.append(patient_record)

# %%
trs.export_sample(records, 2)

# %%
from etl_sdt.transform.data_transfomer import *
from etl_sdt.config import *

trs = DictionaryTransformer(rename_dict)

df = trs.aggregate_dataframe(df)
key_column = 'Patient ID (PID)'
records = trs.restructure_data(df, relevant_features, key_column)


# flat_features = trs._flatten_features(relevant_features)

# df_relevant = trs._filter_relevanat_fetaures( df, flat_features)
# df  = trs._rename_columns(df_relevant, rename_dict)

# %%
import json
from etl_sdt.extract.excel_extractor import *
from etl_sdt.config import *
with open('buffer.json', 'r') as json_file:
    records = json.load(json_file)

# %%
# process to transform in the right data format 

from etl_sdt.extract.excel_extractor import *
from etl_sdt.transform.data_transfomer import *
from etl_sdt.config import *

#1. import and aggregate data 
df = extract_excel(file_path='data/adjumed_export_20240607-174424.xlsx')
trs = DictionaryTransformer(rename_dict)
df = trs.aggregate_dataframe(df)

#2. rename the column
key_column = 'Patient ID (PID)'
df = trs.renaming(df, key_column)

df = trs.transform_dataframe(df, data_format_dict)
key_column = 'Patient ID (PID)'
records = trs.restructure_data(df, relevant_features, key_column)
trs.export_json(records, 'buffer.json')

# %%
trs.export_sample(records, 2)

# %%
# Define the conversion function
def convert_column(column, data_type):
    if data_type == 'datetime':
        return pd.to_datetime(column, errors='coerce', dayfirst=True)
    elif data_type == int:
        numeric_column = pd.to_numeric(column, errors='coerce')
        numeric_column = numeric_column.fillna(-1).astype(int).astype(pd.Int64Dtype())
        return numeric_column.replace(-1, None)
    elif data_type == float:
        return pd.to_numeric(column, errors='coerce')
    else:
        return column

# Define the main transformation function
def transform_dataframe(df, data_format_dict):
    # Convert columns to the appropriate data formats
    for column, data_type in data_format_dict.items():
        if column in df.columns:
            df[column] = convert_column(df[column], data_type)
    return df

# Example usage
data = {
    'age_at_admission': ['25', '30.0', '35', 'invalid', '40.5'],
    'admission_date': ['01-01-2020', '02-01-2020', 'invalid_date', '04-01-2020', '05-01-2020']
}
df = pd.DataFrame(data)
data_format_dict = {'age_at_admission': int, 'admission_date': 'datetime'}

df_new = transform_dataframe(df, data_format_dict)
print(df_new.age_at_admission)

# %%
df_new['Date of biopsy (lowest of 806)_x']

# %%
df_new['duration_of_session_minutes']

# %%
# key_column = 'patient_id'
# df[key_column] = df[key_column].apply(lambda x: ','.join(map(str, x)) if isinstance(x, list) else str(x))
key_column = 'patient_id'
# df = trs._rename_columns(df, trs.rename_dict)

records = []
# key_column = 'patient_id'
for group_idx, (patient_id, group_df) in enumerate(df.groupby(key_column), start=1):
    
    patient_record = {"_id": patient_id}
    index_l=0
    for idx, (index, row) in enumerate(group_df.iterrows(), start=1):
        index_l+=1
        group_name=f'doc_{index_l}'
        patient_record[group_name] ={}
        
        for group, features in relevant_features.items():
        
            group_data = []
        
            
            row_data = {}
            for feature in features:
                renamed_feature = trs.rename_dict.get(feature, feature)
                try:

                    
                    if row[renamed_feature] !=[] and row[renamed_feature] !=None : row_data[renamed_feature] = row[renamed_feature]
                except KeyError:
                    warnings.warn(f"Failed to allocate key: {renamed_feature}")
            
            # Add an enumerated key to distinguish each row in the group
            group_data.append(row_data)
            
            patient_record[group_name][group] = group_data
    
    records.append(patient_record)

# %%
records

# %%
patient_counts = df.groupby('Patient ID (PID)').size().reset_index(name='counts')


patient_counts[patient_counts['counts'] > 2]

# %%
key_column = 'patient_id'
aggregated_df = trs.aggregate_dataframe(df)

# %%
flat_features = df.columns.tolist()
grouped_columns = trs.aggregate_columns_with_same_base(flat_features)
        
# Create a new DataFrame to store aggregated results
aggregated_data = {}

# Iterate through each group and sum the values row-wise
for base_name, group in grouped_columns.items():
    aggregated_data[base_name] = df[group].apply(lambda row: list(row.dropna()), axis=1)

# Create a new DataFrame with the aggregated data
aggregated_df = pd.DataFrame(aggregated_data)

df = aggregated_df.applymap(trs._extract_unique_values)

# %%
records

# %%
with open('buffer.json', 'r') as json_file:
    records = json.load(json_file)

# %%
a =df.groupby(key_column)

a[1]

# %%
key_column = 'patient_id'
df[key_column] = df[key_column].apply(lambda x: ','.join(map(str, x)) if isinstance(x, list) else str(x))

df = trs._rename_columns(df, rename_dict)

records = []
key_column = 'patient_id'
for group_idx, (patient_id, group_df) in enumerate(df.groupby(key_column), start=1):
    
    patient_record = {"_id": patient_id}
    index_l=0
    for idx, (index, row) in enumerate(group_df.iterrows(), start=1):
        index_l+=1
        group_name=f'doc_{index_l}'
        patient_record[group_name] ={}
        
        for group, features in relevant_features.items():
        
            group_data = []
        
            
            row_data = {}
            for feature in features:
                renamed_feature = trs.rename_dict.get(feature, feature)
                try:
                    if row[renamed_feature] !=[] and row[renamed_feature] !=None and pd.notnull(row[renamed_feature]) : row_data[renamed_feature] = row[renamed_feature]
                except KeyError:
                    warnings.warn(f"Failed to allocate key: {renamed_feature}")
            
            # Add an enumerated key to distinguish each row in the group
            group_data.append(row_data)
            
            patient_record[group_name][group] = group_data
    
    records.append(patient_record)

# %%
import json
with open('buffer.json', 'w') as json_file:
    json.dump(records, json_file, indent=4)

# %%
records = trs.restructure_data( aggregated_df, relevant_features, key_column)
trs.print_sample(records, 1)

# %%
import itertools
df =trs._rename_columns(aggregated_df, rename_dict)
all_patient_ids = list(itertools.chain.from_iterable(df['patient_id']))

# Create a new DataFrame with the flattened patient_id values
flat_df = pd.DataFrame({'patient_id': all_patient_ids})

# Group by 'patient_id' and count the number of rows for each unique 'patient_id'
patient_row_counts = flat_df.groupby('patient_id').size().reset_index(name='row_count')

print(patient_row_counts)

# %%
rows_with_two_or_more = df[df['patient_id'].apply(lambda x: len(x) >= 2)]

print(rows_with_two_or_more)

# %%
trs.export_sample(records, 1)

# %%
df = aggregated_df
df  = trs._rename_columns(df, trs.rename_dict)
records = []
for _, row in df.iterrows():
    patient_record = {}
    patient_id = row[key_column]
    for group, features in relevant_features.items():
        group_data = {}

        for feature in features:
            trs._key_allocation(group_data, row, feature)
        
        patient_record[group] = group_data
    
    patient_record["_id"] = patient_id
    records.append(patient_record)

# %%
[item for sublist in relevant_features.values() for item in sublist]

# %%
# restructure data
df = aggregated_df

# flat_features = trs._flatten_features( relevant_features)
# key_column = 'patient_id'
# df_relevant = trs._filter_relevanat_fetaures( df, flat_features)

# %%
 
# df  = trs._rename_columns(df_relevant, rename_dict)

records = []
for _, row in df.iterrows():
    patient_record = {}
    patient_id = row[key_column]
    for group, features in relevant_features.items():
        group_data = {}

        for feature in features:
            renamed_feature = rename_dict.get(feature, feature)
            try:
                group_data[renamed_feature] = row[renamed_feature]
            except KeyError:
                warnings.warn(f"Failed to allocate key: {renamed_feature}")
        
        patient_record[group] = group_data
    
    patient_record["_id"] = patient_id
    records.append(patient_record)

# %%
for i, (key) in enumerate(records):
    if i < 1:
        print(f"{key}")
    else:
        break

# %%
n =1
with open('sample_docs.txt', 'w') as file:
# Print the first x documents and save them to the file
    for i, (key) in enumerate(records):
        if i < n:
            output = f"{key}\n"
            print(output.strip())
            file.write(output)
        else:
            break

# %%
grouped_columns = trs.aggregate_columns_with_same_base(flat_features)
for base_name, group in grouped_columns.items():
    print(f"{base_name}: {group}")

# %%
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *

pdf_path = "data/pdfs/histo definitiv.pdf"
pdf_text = extract_text_from_pdf(pdf_path, detect_vertical_text=False, word_margin=0.1)

ner = PathologyNERExtractor(model_name="alvaroalon2/biobert_genetic_ner") 
pdf_text ="""Striking and important in the present case is the anamnestic information that the tumor has existed since early childhood. 
since early childhood. Purely morphologically (“lipofibromatosis” aspect), the tumor is of the fibroblastic type. 
Fibroblastic form. Originally a so-called superficial CD34-
positive spindle cell tumor and a so-called “fibrous hamartoma of infancy” were originally considered. However 
However, the final immunophenotype (CD34+/S100+/panTRK+) suggests an NTRK-rearranged spindle cell tumor. 
Spindle cell tumor, a molecularly defined tumor entity that has been definitively included in the WHO classification of pediatric tumors. 
classification of pediatric tumors (chapter on soft tissue tumors), while it is included in the WHO 
classification of soft tissue tumors in the chapter on tumors with uncertain differentiation as “emerging”. 
Differentiation. In view of the long history of the disease and the extremely low 
proliferation rate, a benign tumor biology can be assumed. If desired, we can perform a 
molecular pathological confirmation of the NTRK fusion."""
entities = ner.extract_entities(pdf_text)

def extract_entities_dynamic(entities):
    pathology_info = {}
    
    current_entity = None
    current_text = []

    for entity in entities:
        entity_type = entity['entity']
        entity_text = entity['word'].replace('▁', ' ').strip()
        
        if entity_type.startswith('B-'):
            if current_entity is not None and current_text:
                category = current_entity.split('-')[-1].lower()
                if category not in pathology_info:
                    pathology_info[category] = []
                pathology_info[category].append("".join(current_text).replace('##', ''))

            current_entity = entity_type
            current_text = [entity_text]
        elif entity_type.startswith('I-') and current_entity is not None:
            current_text.append(entity_text)

    if current_entity is not None and current_text:
        category = current_entity.split('-')[-1].lower()
        if category not in pathology_info:
            pathology_info[category] = []
        pathology_info[category].append("".join(current_text).replace('##', ''))

    return pathology_info

annotations = extract_entities_dynamic(entities)
print(annotations)

# %%
# Use a pipeline as a high-level helper
from etl_sdt.extract.pdf_extractor import *
from etl_sdt.transform.nlp_processor import *

# pipe = pipeline("token-classification", model="pruas/BENT-PubMedBERT-NER-Gene")

ner = PathologyNERExtractor(model_name="Precious1/Clinical-Biomedical-Named-Entity-Recognition-Using-Scispacy") 

pdf_text ="""Striking and important in the present case is the anamnestic information that the tumor has existed since early childhood. 
since early childhood. Purely morphologically (“lipofibromatosis” aspect), the tumor is of the fibroblastic type. 
Fibroblastic form. Originally a so-called superficial CD34-
positive spindle cell tumor and a so-called “fibrous hamartoma of infancy” were originally considered. However 
However, the final immunophenotype (CD34+/S100+/panTRK+) suggests an NTRK-rearranged spindle cell tumor. 
Spindle cell tumor, a molecularly defined tumor entity that has been definitively included in the WHO classification of pediatric tumors. 
classification of pediatric tumors (chapter on soft tissue tumors), while it is included in the WHO 
classification of soft tissue tumors in the chapter on tumors with uncertain differentiation as “emerging”. 
Differentiation. In view of the long history of the disease and the extremely low 
proliferation rate, a benign tumor biology can be assumed. If desired, we can perform a 
molecular pathological confirmation of the NTRK fusion."""

entities = ner.extract_entities(pdf_text)

def extract_entities_dynamic(entities):
    pathology_info = {}
    
    current_entity = None
    current_text = []

    for entity in entities:
        entity_type = entity['entity']
        entity_text = entity['word'].replace('▁', ' ').strip()
        
        if entity_type.startswith('B'):
            if current_entity is not None and current_text:
                category = current_entity.split('-')[-1].lower()
                if category not in pathology_info:
                    pathology_info[category] = []
                pathology_info[category].append("".join(current_text).replace('##', ''))

            current_entity = entity_type
            current_text = [entity_text]
        elif entity_type.startswith('I') and current_entity is not None:
            current_text.append(entity_text)

    if current_entity is not None and current_text:
        category = current_entity.split('-')[-1].lower()
        if category not in pathology_info:
            pathology_info[category] = []
        pathology_info[category].append("".join(current_text).replace('##', ''))

    return pathology_info

def assemble_entities(entities):
    assembled_text = ""
    current_phrase = ""
    previous_end = None  # Track the end of the previous token for spacing

    for entity in entities:
        token_text = entity['word'].replace('##', '')  # Remove subword indicators
        token_start = entity['start']
        
        # Check if token is part of the same entity (continuous word or phrase)
        if previous_end is not None and token_start == previous_end:
            current_phrase += token_text
        else:
            # If a new word or phrase starts, add the previous phrase to the assembled text
            if current_phrase:
                assembled_text += f"{current_phrase} "
            current_phrase = token_text

        previous_end = entity['end']  # Update end position

    # Add the final phrase to the assembled text
    if current_phrase:
        assembled_text += current_phrase

    return assembled_text.strip() 

print(entities)
# annotations = extract_entities_dynamic(entities)
annotations = assemble_entities(entities)

print(annotations)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# Load BioBERT model and tokenizer
model_name = "dmis-lab/biobert-base-cased-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# Initialize NER pipeline with BioBERT
nlp = pipeline("ner", model=model, tokenizer=tokenizer, grouped_entities=True)

# Sample genetic text to analyze
genetic_text = """Striking and important in the present case is the anamnestic information that the tumor has existed since early childhood. 
since early childhood. Purely morphologically (“lipofibromatosis” aspect), the tumor is of the fibroblastic type. 
Fibroblastic form. Originally a so-called superficial CD34-
positive spindle cell tumor and a so-called “fibrous hamartoma of infancy” were originally considered. However 
However, the final immunophenotype (CD34+/S100+/panTRK+) suggests an NTRK-rearranged spindle cell tumor. 
Spindle cell tumor, a molecularly defined tumor entity that has been definitively included in the WHO classification of pediatric tumors. 
classification of pediatric tumors (chapter on soft tissue tumors), while it is included in the WHO 
classification of soft tissue tumors in the chapter on tumors with uncertain differentiation as “emerging”. 
Differentiation. In view of the long history of the disease and the extremely low 
proliferation rate, a benign tumor biology can be assumed. If desired, we can perform a 
molecular pathological confirmation of the NTRK fusion."""

# Run NER on the text
entities = nlp(genetic_text)

# Display the recognized entities and their labels
print("Recognized Entities:")
for entity in entities:
    print(f"Entity: {entity['word']}, Label: {entity['entity_group']}, Score: {entity['score']:.2f}")

# %%
entities

# %%
ner = PathologyNERExtractor(model_name="jnferfer/treatment-disease-NER") 



column_name = 'summary_decision_further_strategy'
df, new_column_name = ner._rename_column_ner(df, column_name)
        
for index, row in df.iterrows():
    value = row[column_name]
    annotations = []
    if value: 
        ner_tags= ner.extract_entities(value)
        tags =ner.extract_pathology_info( ner_tags)
        
    pathology_info = {
        "genetic": [],
    }

current_entity = None
current_text = []

for entity in entities:
    entity_type = entity['entity']
    entity_text = entity['word']

    if entity_type.startswith('B-t'):
        if current_entity is not None and current_text:
            category = current_entity.split('-')[-1].lower()
            pathology_info[category].append("".join(current_text).replace('##', ''))

        current_entity = entity_type
        current_text = [entity_text]
    elif entity_type.startswith('I-t') and current_entity is not None:
        current_text.append(entity_text)


if current_entity is not None and current_text:
    category = current_entity.split('-')[-1].lower()
    pathology_info[category].append("".join(current_text).replace('##', ''))
    
if  annotations:
    df.at[index, new_column_name] = [annotations]
else: 
    df.at[index, new_column_name] = None

# %%
from etl_sdt.transform.data_transfomer import *

transformer = DictionaryTransformer()
columns = ["column_1 (1)", "column_1 (2)", "column_2 (1)", "column_2"]
grouped_columns = transformer.aggregate_columns_with_same_base(columns)
for base_name, group in grouped_columns.items():
    print(f"{base_name}: {group}")
